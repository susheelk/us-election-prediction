# %%
# Libs
import numpy as np
import pandas as pd
import os

# %%
HOUSE_CSV = '../raw_data/house_results/1976-2018-house.csv'
SAVE_PATH = '../processed_data/house.csv'

# %% [markdown]
# # House Data

# %%
# Read
house = pd.read_csv(HOUSE_CSV, delimiter=',', encoding='utf-8')
house.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic    office  \
# 0  1976  Alabama       AL           1         63        41  US House
# 1  1976  Alabama       AL           1         63        41  US House
# 2  1976  Alabama       AL           1         63        41  US House
# 3  1976  Alabama       AL           1         63        41  US House
# 4  1976  Alabama       AL           1         63        41  US House
#
#    district stage runoff  special         candidate       party  writein  \
# 0         1   gen  False    False    Bill Davenport    democrat    False
# 1         1   gen  False    False      Jack Edwards  republican    False
# 2         1   gen  False    False               NaN         NaN     True
# 3         2   gen  False    False  J. Carole Keahey    democrat    False
# 4         2   gen  False    False               NaN         NaN     True
#
#     mode  candidatevotes  totalvotes  unofficial   version
# ...

# %%
house = house.groupby(['state', 'state_po', 'year', 'party'])[['candidatevotes', 'totalvotes']].sum().reset_index()

# %%
house['pop_percent'] = house['candidatevotes'] / house['totalvotes']

# %%
house = house[['state', 'state_po', 'year', 'party', 'pop_percent']]
house.head()
# Out:
#      state state_po  year              party  pop_percent
# 0  Alabama       AL  1976           democrat     0.677774
# 1  Alabama       AL  1976  national democrat     0.006282
# 2  Alabama       AL  1976        prohibition     0.010282
# 3  Alabama       AL  1976         republican     0.483029
# 4  Alabama       AL  1978       conservative     0.039641

# %%
house = house[house.party.isin(['democrat', 'republican'])]
house.head()
# Out:
#      state state_po  year       party  pop_percent
# 0  Alabama       AL  1976    democrat     0.677774
# 3  Alabama       AL  1976  republican     0.483029
# 5  Alabama       AL  1978    democrat     0.684382
# 7  Alabama       AL  1978  republican     0.482370
# 8  Alabama       AL  1980    democrat     0.700725

# %%
house = house.pivot_table(index=['state', 'state_po', 'year'], columns=['party'], values='pop_percent').fillna(0).reset_index()

# %%
house[house['state'] == 'Alabama']
# Out:
# party    state state_po  year  democrat  republican
# 0      Alabama       AL  1976  0.677774    0.483029
# 1      Alabama       AL  1978  0.684382    0.482370
# 2      Alabama       AL  1980  0.700725    0.547513
# 3      Alabama       AL  1982  0.704028    0.447112
# 4      Alabama       AL  1984  0.715472    0.499923
# 5      Alabama       AL  1986  0.666029    0.391170
# 6      Alabama       AL  1988  0.687523    0.470411
# 7      Alabama       AL  1990  0.739267    0.424824
# 8      Alabama       AL  1992  0.558865    0.401333
# 9      Alabama       AL  1994  0.496991    0.561945
# 10     Alabama       AL  1996  0.446688    0.534838
# 11     Alabama       AL  1998  0.495150    0.618612
# 12     Alabama       AL  2000  0.563483    0.690722
# 13     Alabama       AL  2002  0.557667    0.630032
# 14     Alabama       AL  2004  0.464628    0.602232
# 15     Alabama       AL  2006  0.515526    0.730134
# 16     Alabama       AL  2008  0.530683    0.690395
# ...

# %%
house.to_csv(SAVE_PATH, index=False)

# %%
# house.groupby(['state', 'year', 'party']).sum()

# %%
# house['party'] = house.index.get_level_values('party')

# %%
# house[house.index.get_level_values('state') == 'California']
